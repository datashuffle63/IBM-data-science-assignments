# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>
#
# # Simple APIs
#
# ## Random User and Fruitvice API Examples
#
# Estimated time needed: **25** minutes
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# *   Load and use RandomUser API, using `RandomUser()` Python library
# *   Load and use Fruitvice API, using `requests` Python library

# %% [markdown]
# The purpose of this notebook is to provide more examples on how to use simple APIs. As you have already learned from previous videos and notebooks, API stands for Application Programming Interface and is a software intermediary that allows two applications to talk to each other.
#
# The advantages of using APIs:
#
# *   **Automation**. Less human effort is required and workflows can be easily updated to become faster and more\
#     productive.
# *   **Efficiency**. It allows to use the capabilities of one of the already developed APIs than to try to
#     independently implement some functionality from scratch.
#
# The disadvantage of using APIs:
#
# *   **Secirity**. If the API is poorly integrated, it means it will be vulnerable to attacks, resulting in data\
#     breeches or losses having financial or reputation implications.
#
# One of the applications we will use in this notebook is Random User Generator. RandomUser is an open-source, free API providing developers with randomly generated users to be used as placeholders for testing purposes. This makes the tool similar to Lorem Ipsum, but is a placeholder for people instead of text. The API can return multiple results, as well as specify generated user details such as gender, email, image, username, address, title, first and last name, and more. More information on [RandomUser](https://randomuser.me/documentation?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2022-01-01#intro) can be found here.
#
# Another example of simple API we will use in this notebook is Fruitvice application. The Fruitvice API webservice which provides data for all kinds of fruit! You can use Fruityvice to find out interesting information about fruit and educate yourself. The webservice is completely free to use and contribute to.

# %% [markdown]
# ## Example 1: RandomUser API
#
# Bellow are Get Methods parameters that we can generate. For more information on the parameters, please visit this [documentation](https://randomuser.me/documentation?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2022-01-01) page.

# %% [markdown]
# ## **Get Methods**
#
# *   get_cell()
# *   get_city()
# *   get_dob()
# *   get_email()
# *   get_first_name()
# *   get_full_name()
# *   get_gender()
# *   get_id()
# *   get_id_number()
# *   get_id_type()
# *   get_info()
# *   get_last_name()
# *   get_login_md5()
# *   get_login_salt()
# *   get_login_sha1()
# *   get_login_sha256()
# *   get_nat()
# *   get_password()
# *   get_phone()
# *   get_picture()
# *   get_postcode()
# *   get_registered()
# *   get_state()
# *   get_street()
# *   get_username()
# *   get_zipcode()

# %% [markdown]
# To start using the API you can install the `randomuser` library running the `pip install` command.

# %%
# !pip install randomuser
# Out:
# Collecting randomuser
#   Downloading randomuser-1.6.tar.gz (5.0 kB)
# Building wheels for collected packages: randomuser
#   Building wheel for randomuser (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /home/forkboi/Workspace/Repositories/IBM-data-science-assignments/env/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-b2unutud/randomuser/setup.py'"'"'; __file__='"'"'/tmp/pip-install-b2unutud/randomuser/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-ib39szyq
#        cwd: /tmp/pip-install-b2unutud/randomuser/
#   Complete output (6 lines):
#   usage: setup.py [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#      or: setup.py --help [cmd1 cmd2 ...]
#      or: setup.py --help-commands
#      or: setup.py cmd --help
#
#   error: invalid command 'bdist_wheel'
#   ----------------------------------------
#   ERROR: Failed building wheel for randomuser
#   Running setup.py clean for randomuser
# Failed to build randomuser
# Installing collected packages: randomuser
#     Running setup.py install for randomuser ... done
# Successfully installed randomuser-1.6

# %% [markdown]
# Then, we will load the necessary libraries.

# %%
from randomuser import RandomUser
import pandas as pd

# %% [markdown]
# First, we will create a random user object, r.

# %%
r = RandomUser()

# %% [markdown]
# Then, using `generate_users()` function, we get a list of random 10 users.

# %%
some_list = r.generate_users(10)

# %%
some_list
# Out:
# [<randomuser.RandomUser at 0x7f84540e0700>,
#  <randomuser.RandomUser at 0x7f84540e0490>,
#  <randomuser.RandomUser at 0x7f84540e0ac0>,
#  <randomuser.RandomUser at 0x7f84540e0b80>,
#  <randomuser.RandomUser at 0x7f84540e0430>,
#  <randomuser.RandomUser at 0x7f84540e0940>,
#  <randomuser.RandomUser at 0x7f84540e0670>,
#  <randomuser.RandomUser at 0x7f84540e0730>,
#  <randomuser.RandomUser at 0x7f84540e0520>,
#  <randomuser.RandomUser at 0x7f84540e04c0>]

# %% [markdown]
# The **"Get Methods"** functions mentioned at the beginning of this notebook, can generate the required parameters to construct a dataset. For example, to get full name, we call `get_full_name()` function.

# %%
name = r.get_full_name()

# %% [markdown]
# Let's say we only need 10 users with full names and their email addresses. We can write a "for-loop" to print these 10 users.

# %%
for user in some_list:
    print (user.get_full_name()," ",user.get_email())
# Out:
# Trygve Lorentsen   trygve.lorentsen@example.com
# Leonora Nilsen   leonora.nilsen@example.com
# Mirco Möbus   mirco.mobus@example.com
# Silje Hansen   silje.hansen@example.com
# Kelly Long   kelly.long@example.com
# Melissa Walters   melissa.walters@example.com
# کیانا احمدی   khyn.hmdy@example.com
# Annabelle Grewal   annabelle.grewal@example.com
# Delphine Novak   delphine.novak@example.com
# Iiris Lammi   iiris.lammi@example.com

# %% [markdown]
# ## Exercise 1
#
# In this Exercise, generate photos of the random 5 users.

# %%
## Write your code here
another_list = r.generate_users(5)

imgs = []
for user in another_list:
    imgs.append(user.get_picture())
    
for img in imgs:
    print(img)
# Out:
# https://randomuser.me/api/portraits/women/53.jpg
# https://randomuser.me/api/portraits/women/49.jpg
# https://randomuser.me/api/portraits/women/51.jpg
# https://randomuser.me/api/portraits/women/40.jpg
# https://randomuser.me/api/portraits/women/82.jpg

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# for user in some_list:
#     print (user.get_picture())
# ```
#
# </details>

# %% [markdown]
# To generate a table with information about the users, we can write a function containing all desirable parameters. For example, name, gender, city, etc. The parameters will depend on the requirements of the test to be performed. We call the Get Methods, listed at the beginning of this notebook. Then, we return pandas dataframe with the users.

# %%
def get_users():
    users =[]
     
    for user in RandomUser.generate_users(10):
        users.append({"Name":user.get_full_name(),"Gender":user.get_gender(),"City":user.get_city(),"State":user.get_state(),"Email":user.get_email(), "DOB":user.get_dob(),"Picture":user.get_picture()})
      
    return pd.DataFrame(users)

# %%
get_users()
# Out:
#                 Name  Gender              City              State  \
# 0        Barış Akşit    male         Çanakkale            Bayburt
# 1      Noah Kowalski    male           Chatham       Saskatchewan
# 2  Tanja Engelbrecht  female        Teuschnitz    Rheinland-Pfalz
# 3      Scarlett Wood  female         Whangarei  Manawatu-Wanganui
# 4    Sophie Thompson  female         Greymouth           Gisborne
# 5    Aubree Andersen  female           Hampton            Alberta
# 6     Régia Monteiro  female           Atibaia          Tocantins
# 7      Gaëtan Arnaud    male  Aulnay-sous-Bois     Saône-et-Loire
# 8    Samuel Robinson    male          Blenheim        Marlborough
# 9       Leah Johnson  female            Cairns           Victoria
#
#                            Email                       DOB  \
# 0        baris.aksit@example.com  1961-04-16T15:59:25.936Z
# 1      noah.kowalski@example.com  1988-11-11T17:30:53.333Z
# 2  tanja.engelbrecht@example.com  1974-05-06T02:15:52.858Z
# 3      scarlett.wood@example.com  1980-01-01T03:31:38.907Z
# 4    sophie.thompson@example.com  1949-02-27T09:45:57.399Z
# 5    aubree.andersen@example.com  1965-01-08T13:37:21.683Z
# 6     regia.monteiro@example.com  1979-05-30T14:24:28.620Z
# 7      gaetan.arnaud@example.com  1960-09-20T21:45:40.345Z
# 8    samuel.robinson@example.com  1974-07-14T00:02:54.400Z
# 9       leah.johnson@example.com  1956-01-16T15:38:19.395Z
#
#                                             Picture
# 0    https://randomuser.me/api/portraits/men/29.jpg
# 1    https://randomuser.me/api/portraits/men/55.jpg
# 2  https://randomuser.me/api/portraits/women/83.jpg
# 3  https://randomuser.me/api/portraits/women/53.jpg
# 4  https://randomuser.me/api/portraits/women/72.jpg
# 5  https://randomuser.me/api/portraits/women/19.jpg
# 6  https://randomuser.me/api/portraits/women/51.jpg
# 7    https://randomuser.me/api/portraits/men/76.jpg
# 8    https://randomuser.me/api/portraits/men/31.jpg
# 9  https://randomuser.me/api/portraits/women/45.jpg

# %%
df1 = pd.DataFrame(get_users())

# %% [markdown]
# Now we have a *pandas* dataframe that can be used for any testing purposes that the tester might have.

# %% [markdown]
# ## Example 2: Fruitvice API
#
# Another, more common way to use APIs, is through `requests` library. The next lab, Requests and HTTP, will contain more information about requests.
#
# We will start by importing all required libraries.

# %%
import requests
import json

# %% [markdown]
# We will obtain the [fruitvice](https://www.fruityvice.com/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2022-01-01) API data using `requests.get("url")` function. The data is in a json format.

# %%
data = requests.get("https://www.fruityvice.com/api/fruit/all")

# %% [markdown]
# We will retrieve results using `json.loads()` function.

# %%
results = json.loads(data.text)

# %% [markdown]
# We will convert our json data into *pandas* data frame.

# %%
pd.DataFrame(results)
# Out:
#          genus          name  id           family             order  \
# 0        Malus         Apple   6         Rosaceae           Rosales
# 1       Prunus       Apricot  35         Rosaceae           Rosales
# 2         Musa        Banana   1         Musaceae      Zingiberales
# 3        Rubus    Blackberry  64         Rosaceae           Rosales
# 4     Fragaria     Blueberry  33         Rosaceae           Rosales
# 5       Prunus        Cherry   9         Rosaceae              None
# 6        Durio        Durian  60        Malvaceae          Malvales
# 7        Ficus           Fig  68         Moraceae           Rosales
# 8        Ribes    Gooseberry  69  Grossulariaceae      Saxifragales
# 9        Vitis        Grapes  47         Vitaceae           Vitales
# 10       Malus    GreenApple  72         Rosaceae           Rosales
# 11     Psidium         Guava  37        Myrtaceae          Myrtales
# 12     Apteryx          Kiwi  66    Actinidiaceae  Struthioniformes
# 13      Citrus         Lemon  26         Rutaceae        Sapindales
# 14      Citrus          Lime  44         Rutaceae        Sapindales
# 15   Vaccinium   Lingonberry  65        Ericaceae          Ericales
# 16      Litchi        Lychee  67      Sapindaceae        Sapindales
# 17   Mangifera         Mango  27    Anacardiaceae        Sapindales
# 18     Cucumis         Melon  41    Cucurbitaceae     Cucurbitaceae
# 19      Citrus        Orange   2         Rutaceae        Sapindales
# 20      Carica        Papaya  42       Caricaceae         Caricacea
# 21  Passiflora  Passionfruit  70   Passifloraceae      Malpighiales
# 22       Pyrus          Pear   4         Rosaceae           Rosales
# 23   Diospyros     Persimmon  52        Ebenaceae           Rosales
# 24      Ananas     Pineapple  10     Bromeliaceae            Poales
# 25      Prunus          Plum  71         Rosaceae           Rosales
# 26       Rubus     Raspberry  23         Rosaceae           Rosales
# 27    Fragaria    Strawberry   3         Rosaceae           Rosales
# 28     Solanum        Tomato   5       Solanaceae         Solanales
# 29    Spondias          Umbu  73    Anacardiaceae                 0
# 30   Citrullus    Watermelon  25    Cucurbitaceae      Cucurbitales
#
#                                            nutritions
# 0   {'carbohydrates': 11.4, 'protein': 0.3, 'fat':...
# 1   {'carbohydrates': 3.9, 'protein': 0.5, 'fat': ...
# 2   {'carbohydrates': 22, 'protein': 1, 'fat': 0.2...
# 3   {'carbohydrates': 9, 'protein': 1.3, 'fat': 0....
# 4   {'carbohydrates': 5.5, 'protein': 0, 'fat': 0....
# 5   {'carbohydrates': 12, 'protein': 1, 'fat': 0.3...
# 6   {'carbohydrates': 27.1, 'protein': 1.5, 'fat':...
# 7   {'carbohydrates': 19, 'protein': 0.8, 'fat': 0...
# 8   {'carbohydrates': 10, 'protein': 0.9, 'fat': 0...
# 9   {'carbohydrates': 18.1, 'protein': 0.72, 'fat'...
# 10  {'carbohydrates': 3.1, 'protein': 0.4, 'fat': ...
# 11  {'carbohydrates': 14, 'protein': 2.6, 'fat': 1...
# 12  {'carbohydrates': 15, 'protein': 1.1, 'fat': 0...
# 13  {'carbohydrates': 9, 'protein': 1.1, 'fat': 0....
# 14  {'carbohydrates': 8.4, 'protein': 0.3, 'fat': ...
# 15  {'carbohydrates': 11.3, 'protein': 0.75, 'fat'...
# 16  {'carbohydrates': 17, 'protein': 0.8, 'fat': 0...
# 17  {'carbohydrates': 15, 'protein': 0.82, 'fat': ...
# 18  {'carbohydrates': 8, 'protein': 0, 'fat': 0, '...
# 19  {'carbohydrates': 8.3, 'protein': 1, 'fat': 0....
# 20  {'carbohydrates': 11, 'protein': 0, 'fat': 0.4...
# 21  {'carbohydrates': 22.4, 'protein': 2.2, 'fat':...
# 22  {'carbohydrates': 15, 'protein': 0.4, 'fat': 0...
# 23  {'carbohydrates': 18, 'protein': 0, 'fat': 0, ...
# 24  {'carbohydrates': 13.12, 'protein': 0.54, 'fat...
# 25  {'carbohydrates': 11.4, 'protein': 0.7, 'fat':...
# 26  {'carbohydrates': 12, 'protein': 1.2, 'fat': 0...
# 27  {'carbohydrates': 5.5, 'protein': 0.8, 'fat': ...
# 28  {'carbohydrates': 3.9, 'protein': 0.9, 'fat': ...
# 29  {'carbohydrates': 0, 'protein': 0, 'fat': 0, '...
# 30  {'carbohydrates': 8, 'protein': 0.6, 'fat': 0....

# %% [markdown]
# The result is in a nested json format. The 'nutrition' column contains multiple subcolumns, so the data needs to be 'flattened' or normalized.

# %%
df2 = pd.json_normalize(results)

# %%
df2
# Out:
#          genus          name  id           family             order  \
# 0        Malus         Apple   6         Rosaceae           Rosales
# 1       Prunus       Apricot  35         Rosaceae           Rosales
# 2         Musa        Banana   1         Musaceae      Zingiberales
# 3        Rubus    Blackberry  64         Rosaceae           Rosales
# 4     Fragaria     Blueberry  33         Rosaceae           Rosales
# 5       Prunus        Cherry   9         Rosaceae              None
# 6        Durio        Durian  60        Malvaceae          Malvales
# 7        Ficus           Fig  68         Moraceae           Rosales
# 8        Ribes    Gooseberry  69  Grossulariaceae      Saxifragales
# 9        Vitis        Grapes  47         Vitaceae           Vitales
# 10       Malus    GreenApple  72         Rosaceae           Rosales
# 11     Psidium         Guava  37        Myrtaceae          Myrtales
# 12     Apteryx          Kiwi  66    Actinidiaceae  Struthioniformes
# 13      Citrus         Lemon  26         Rutaceae        Sapindales
# 14      Citrus          Lime  44         Rutaceae        Sapindales
# 15   Vaccinium   Lingonberry  65        Ericaceae          Ericales
# 16      Litchi        Lychee  67      Sapindaceae        Sapindales
# 17   Mangifera         Mango  27    Anacardiaceae        Sapindales
# 18     Cucumis         Melon  41    Cucurbitaceae     Cucurbitaceae
# 19      Citrus        Orange   2         Rutaceae        Sapindales
# 20      Carica        Papaya  42       Caricaceae         Caricacea
# 21  Passiflora  Passionfruit  70   Passifloraceae      Malpighiales
# 22       Pyrus          Pear   4         Rosaceae           Rosales
# 23   Diospyros     Persimmon  52        Ebenaceae           Rosales
# 24      Ananas     Pineapple  10     Bromeliaceae            Poales
# 25      Prunus          Plum  71         Rosaceae           Rosales
# 26       Rubus     Raspberry  23         Rosaceae           Rosales
# 27    Fragaria    Strawberry   3         Rosaceae           Rosales
# 28     Solanum        Tomato   5       Solanaceae         Solanales
# 29    Spondias          Umbu  73    Anacardiaceae                 0
# 30   Citrullus    Watermelon  25    Cucurbitaceae      Cucurbitales
#
#     nutritions.carbohydrates  nutritions.protein  nutritions.fat  \
# 0                      11.40                0.30            0.40
# 1                       3.90                0.50            0.10
# 2                      22.00                1.00            0.20
# 3                       9.00                1.30            0.40
# 4                       5.50                0.00            0.40
# 5                      12.00                1.00            0.30
# 6                      27.10                1.50            5.30
# 7                      19.00                0.80            0.30
# 8                      10.00                0.90            0.60
# 9                      18.10                0.72            0.16
# 10                      3.10                0.40            0.10
# 11                     14.00                2.60            1.00
# 12                     15.00                1.10            0.50
# 13                      9.00                1.10            0.30
# 14                      8.40                0.30            0.10
# 15                     11.30                0.75            0.34
# 16                     17.00                0.80            0.44
# 17                     15.00                0.82            0.38
# 18                      8.00                0.00            0.00
# 19                      8.30                1.00            0.20
# 20                     11.00                0.00            0.40
# 21                     22.40                2.20            0.70
# 22                     15.00                0.40            0.10
# 23                     18.00                0.00            0.00
# 24                     13.12                0.54            0.12
# 25                     11.40                0.70            0.28
# 26                     12.00                1.20            0.70
# 27                      5.50                0.80            0.40
# 28                      3.90                0.90            0.20
# 29                      0.00                0.00            0.00
# 30                      8.00                0.60            0.20
#
#     nutritions.calories  nutritions.sugar
# 0                    52             10.30
# 1                    15              3.20
# 2                    96             17.20
# 3                    40              4.50
# 4                    29              5.40
# 5                    50              8.00
# 6                   147              6.75
# 7                    74             16.00
# 8                    44              0.00
# 9                    69             15.48
# 10                   21              6.40
# 11                   68              9.00
# 12                   61              9.00
# 13                   29              2.50
# 14                   25              1.70
# 15                   50              5.74
# 16                   66             15.00
# 17                   60             13.70
# 18                   34              8.00
# 19                   43              8.20
# 20                   43              1.00
# 21                   97             11.20
# 22                   57             10.00
# 23                   81             18.00
# 24                   50              9.85
# 25                   46              9.92
# 26                   53              4.40
# 27                   29              5.40
# 28                   74              2.60
# 29                    0              0.00
# 30                   30              6.00

# %% [markdown]
# Let's see if we can extract some information from this dataframe. Perhaps, we need to know the family and genus of a cherry.

# %%
cherry = df2.loc[df2["name"] == 'Cherry']
(cherry.iloc[0]['family']) , (cherry.iloc[0]['genus'])
# Out:
# ('Rosaceae', 'Prunus')

# %% [markdown]
# ## Exercise 2
#
# In this Exercise, find out how many calories are contained in a banana.

# %%
# Write your code here
banana = df2.loc[df2['name'] == 'Banana']
banana.iloc[0]['nutritions.calories']
# Out:
# 96

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# cal_banana = df2.loc[df2["name"] == 'Banana']
# cal_banana.iloc[0]['nutritions.calories']
# ```
#
# </details>

# %% [markdown]
# ## Exercise 3
#
# This [page](https://github.com/public-apis/public-apis#animals) contains a list of free public APIs. Choose any API of your interest and use it to load/extract some information, as shown in the example above.
#
# 1.  Using `requests.get("url")` function, load your data.

# %%
# Write your code here
appli = requests.get('https://random-data-api.com/api/v2/appliances?size=100&is_json=true')

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# data2 = requests.get("https://www.fishwatch.gov/api/species")
# ```
#
# </details>

# %% [markdown]
# 2.  Retrieve results using `json.loads()` function.

# %%
# Write your code here
res = json.loads(appli.text)
print(res)
# Out:
# [{'id': 9161, 'uid': '8ee2500f-02e8-4346-aa1b-5819787679d0', 'brand': 'Blue Star', 'equipment': 'Television'}, {'id': 5384, 'uid': 'a7929263-3ce7-4648-85fa-b91ed4ef434f', 'brand': 'KitchenAid', 'equipment': 'Patio heater'}, {'id': 7407, 'uid': '16aac38c-728f-442c-b04d-f3ccf9ef4534', 'brand': 'LG', 'equipment': 'Ceiling fan'}, {'id': 3616, 'uid': 'd8c7d4b9-7316-4656-a454-bd4e37f3c416', 'brand': 'Amana', 'equipment': 'Domestic robot'}, {'id': 2783, 'uid': '5842da7f-f4b8-459b-b363-77a249edb243', 'brand': 'Fagor', 'equipment': 'Tie press'}, {'id': 9598, 'uid': '819d4a2e-7b53-4d02-95e7-a21a779a246d', 'brand': 'Fagor', 'equipment': 'Combo washer dryer'}, {'id': 3892, 'uid': 'ed6117bd-ffa5-42de-b10f-ac3901445a8e', 'brand': 'Sharp', 'equipment': 'Evaporative cooler'}, {'id': 7049, 'uid': '9a5fcd2a-8fd2-4ba8-9b05-a245e4a071fb', 'brand': 'IKEA', 'equipment': 'Patio heater'}, {'id': 990, 'uid': '1d447382-5e40-426d-91eb-87b44be01788', 'brand': 'Admiral', 'equipment': 'Mangle (machine)'}, {'id': 9434, 'uid': 'f8b54060-4a27-4891-ae39-45df1de441a1', 'brand': 'Siemens', 'equipment': 'Box mangle'}, {'id': 2464, 'uid': 'e1b65a8f-e21a-4088-966b-d2b0b1d51804', 'brand': 'Franke', 'equipment': 'Aroma lamp'}, {'id': 3868, 'uid': '42d0d03e-4593-4573-956b-309cfa49bd34', 'brand': 'Admiral', 'equipment': 'Television'}, {'id': 9835, 'uid': 'b0814c55-a5fb-4fcd-922e-6553b84231b0', 'brand': 'Electrolux', 'equipment': 'HVAC'}, {'id': 1345, 'uid': '352b0548-6bda-45f4-a84c-643437be79d5', 'brand': 'Sharp', 'equipment': 'Micathermic heater'}, {'id': 6865, 'uid': '254f4bd1-7c57-4250-8002-4fcc824fc5d2', 'brand': 'Franke', 'equipment': 'Icebox'}, {'id': 3099, 'uid': '87636cb7-ae95-41df-abc7-21527a3a0455', 'brand': 'Bosch', 'equipment': 'Ceiling fan'}, {'id': 1401, 'uid': '0faa5664-2924-438c-bd9d-44eb73f1f0ef', 'brand': 'Bosch', 'equipment': 'Gas appliance'}, {'id': 4111, 'uid': '1d1f3235-cf1f-42dd-b1ad-9feb95cfdba8', 'brand': 'Samsung', 'equipment': 'Stove'}, {'id': 4680, 'uid': '9b7465c1-2db2-41f2-b5ab-60dcf0a842e8', 'brand': 'Whirlpool', 'equipment': 'Water heater'}, {'id': 3030, 'uid': '13a28855-aa41-4826-8d89-66e9047c9c7f', 'brand': 'Samsung', 'equipment': 'Mousetrap'}, {'id': 7650, 'uid': '266ef86f-59e4-4c9f-89af-55e606f2ca97', 'brand': 'Fagor', 'equipment': 'Refrigerator'}, {'id': 4187, 'uid': '8f1b7b00-5287-4b62-a4ba-3dd2f179f373', 'brand': 'Blue Star', 'equipment': 'Washing machine'}, {'id': 8305, 'uid': 'f7472463-e0e7-4d0a-b5da-f091f9aba1b3', 'brand': 'Whirlpool', 'equipment': 'Tie press'}, {'id': 5886, 'uid': '6485281b-4926-4c6e-a222-ea4eae9d6084', 'brand': 'Sharp', 'equipment': 'Dishwasher'}, {'id': 3872, 'uid': 'f951869f-f9ae-44cc-967f-ba7efaa10117', 'brand': 'Amana', 'equipment': 'Vacuum cleaner'}, {'id': 1471, 'uid': 'a58cf9db-a984-443e-931d-c0f0c8415e7b', 'brand': 'KitchenAid', 'equipment': 'Water heater'}, {'id': 7368, 'uid': 'dbf35d0d-3a46-410a-ab8f-279898ec9981', 'brand': 'Samsung', 'equipment': 'Oil heater'}, {'id': 1184, 'uid': 'eca485e0-3475-40d2-8228-650f6951c906', 'brand': 'IKEA', 'equipment': 'Drawer dishwasher'}, {'id': 5343, 'uid': 'adc8cdd1-980a-48fb-92c8-bc57001a9d53', 'brand': 'Siemens', 'equipment': 'Air ioniser'}, {'id': 5824, 'uid': '3fea9f31-ce36-445e-aa86-68c62a5c7214', 'brand': 'Admiral', 'equipment': 'Television'}, {'id': 9273, 'uid': '676aa148-aab9-42e2-b3f9-a13c4d735d23', 'brand': 'Sharp', 'equipment': 'Bachelor griller'}, {'id': 9770, 'uid': '3d7a5eb0-2aee-44db-a11c-ab9bbf0dde0b', 'brand': 'LG', 'equipment': 'Dishwasher'}, {'id': 7717, 'uid': '907ca4cd-8a55-42df-88f4-07671d4fe179', 'brand': 'Franke', 'equipment': 'Toaster and toaster ovens'}, {'id': 3496, 'uid': '9ff8bb3e-ae3d-44ef-ba6d-be11e1898f82', 'brand': 'Franke', 'equipment': 'Space heater'}, {'id': 8129, 'uid': '5501be45-dda8-4146-bcde-10178981d0fb', 'brand': 'Admiral', 'equipment': 'Steam mop'}, {'id': 2107, 'uid': '59dbdb72-b62b-41ad-9137-2d4786083ff1', 'brand': 'LG', 'equipment': 'Evaporative cooler'}, {'id': 6292, 'uid': '9b2ddd8b-5d20-4cf5-9b90-e5775bcc7a1d', 'bra ...

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# results2 = json.loads(data2.text)
# ```
#
# </details>

# %% [markdown]
# 3.  Convert json data into *pandas* data frame.

# %%
# Write your code here
pd.DataFrame(res)
# Out:
#       id                                   uid       brand  \
# 0   9161  8ee2500f-02e8-4346-aa1b-5819787679d0   Blue Star
# 1   5384  a7929263-3ce7-4648-85fa-b91ed4ef434f  KitchenAid
# 2   7407  16aac38c-728f-442c-b04d-f3ccf9ef4534          LG
# 3   3616  d8c7d4b9-7316-4656-a454-bd4e37f3c416       Amana
# 4   2783  5842da7f-f4b8-459b-b363-77a249edb243       Fagor
# ..   ...                                   ...         ...
# 95  5802  ea02964f-f9f7-4076-a90b-acbd0c341dad   Whirlpool
# 96  2148  28c0f3a1-922d-4065-8955-b16c07865a66       Sharp
# 97  8067  e428d1ef-ffdb-4ae9-8c36-c249bba73018          LG
# 98  7151  024c28ad-d9f1-4812-96c0-b43f2a57b104      Franke
# 99   819  b66d0265-b4f4-47c3-9dc6-bbf5b6274a06   Whirlpool
#
#                equipment
# 0             Television
# 1           Patio heater
# 2            Ceiling fan
# 3         Domestic robot
# 4              Tie press
# ..                   ...
# 95     Drawer dishwasher
# 96         Clothes dryer
# 97  Dish draining closet
# 98   Cold-pressed juicer
# 99        Microwave oven
#
# [100 rows x 4 columns]

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df3 = pd.DataFrame(results2)
# df3
# ```
#
# </details>

# %% [markdown]
# # Congratulations! - You have completed the lab

# %% [markdown]
# ## Author
#
# [Svitlana Kramar](https://www.linkedin.com/in/svitlana-kramar?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2022-01-01)
#
# Svitlana is a master’s degree Data Science and Analytics student at University of Calgary, who enjoys travelling, learning new languages and cultures and loves spreading her passion for Data Science.

# %% [markdown]
# Copyright © 2020 IBM Corporation. All rights reserved.
